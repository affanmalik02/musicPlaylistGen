# %% [markdown]
# <a href="https://colab.research.google.com/github/affanmalik02/dlmusicplaylist/blob/main/dlplaylistgenerator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Preparation
# This section imports songs from the [GTZAN dataset](https://www.kaggle.com/datasets/andradaolteanu/gtzan-dataset-music-genre-classification). This has 30 second clips of 100 songs from 10 genres. The songs come pre-processed in the Mel-Spectrogram format which is what we will use to train our CNN. The path to the spectrograms is saved in the spectrogramsPath variable. The (genre, image-array) pairs are saved into the array called data.

# %%
import kagglehub
import pandas as pd
import os
from PIL import Image
import numpy as np

# %%
path = kagglehub.dataset_download("andradaolteanu/gtzan-dataset-music-genre-classification")

print("Path to dataset files:", path)
spectrogramsPath = path + '/Data/images_original'
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/andradaolteanu/gtzan-dataset-music-genre-classification?dataset_version_number=1...
# 100%|██████████| 1.21G/1.21G [00:13<00:00, 99.0MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/andradaolteanu/gtzan-dataset-music-genre-classification/versions/1

# %%
data = []
length = len(spectrogramsPath) + 1

for root, dirs, files in os.walk(spectrogramsPath):
  genre = root[length:]
  for f in files:
    path = spectrogramsPath + '/' + genre + '/' + f
    img = Image.open(path)
    d = (genre, np.array(img))
    data.append(d)

# %%
import matplotlib.pyplot as plt

# Plot the first 5 spectrogram images
for i in range(5):
    genre, img_array = data[i]
    plt.imshow(img_array, cmap='viridis')
    plt.title(f"Genre: {genre}")
    plt.show()
